# %%
import pandas as pd

# %%
dc = pd.read_csv("DC_Properties.csv", sep=',', dtype={'a': str})

# %%
dc.head(10)
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
# 5           5       3          2  Hot Water Rad  Y        1.0     10      5
# 6           6       1          0      Warm Cool  Y        2.0      5      2
# 7           7       3          1  Hot Water Rad  Y        2.0      8      4
# 8           8       3          1      Warm Cool  Y        2.0      7      3
# 9           9       1          1  Hot Water Rad  Y        1.0      6      2
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# ...

# %%
dc = pd.read_csv("DC_Properties.csv", sep=',', dtype="unicode")

# %%
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158957 entries, 0 to 158956
# Data columns (total 49 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          158957 non-null  object
#  1   BATHRM              158957 non-null  object
#  2   HF_BATHRM           158957 non-null  object
#  3   HEAT                158957 non-null  object
#  4   AC                  158957 non-null  object
#  5   NUM_UNITS           106696 non-null  object
#  6   ROOMS               158957 non-null  object
#  7   BEDRM               158957 non-null  object
#  8   AYB                 158686 non-null  object
#  9   YR_RMDL             80928 non-null   object
#  10  EYB                 158957 non-null  object
#  11  STORIES             106652 non-null  object
#  12  SALEDATE            132187 non-null  object
#  13  PRICE               98216 non-null   object
#  14  QUALIFIED           158957 non-null  object
# ...
